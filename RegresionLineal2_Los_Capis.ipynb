# %% [markdown]
# <a href="https://colab.research.google.com/github/MelaOchoa/LosCapis/blob/Taller2_ModelosSupervisado/RegresionLineal2_Los_Capis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

datos = pd.read_csv("car.csv")

# %%
datos.head()
# Out:
#    Car ID  Brand  Year  Engine Size Fuel Type Transmission  Mileage Condition  \
# 0       1  Tesla  2016          2.3    Petrol       Manual   114832       New
# 1       2    BMW  2018          4.4  Electric       Manual   143190      Used
# 2       3   Audi  2013          4.5  Electric       Manual   181601       New
# 3       4  Tesla  2011          4.1    Diesel    Automatic    68682       New
# 4       5   Ford  2009          2.6    Diesel       Manual   223009  Like New
#
#       Price     Model
# 0  26613.92   Model X
# 1  14679.61  5 Series
# 2  44402.61        A4
# 3  86374.33   Model Y
# 4  73577.10   Mustang

# %%
# Eliminar la columna 'Car ID'
datos = datos.drop(columns=["Car ID"])

# %%
datos.head()
# Out:
#    Brand  Year  Engine Size Fuel Type Transmission  Mileage Condition  \
# 0  Tesla  2016          2.3    Petrol       Manual   114832       New
# 1    BMW  2018          4.4  Electric       Manual   143190      Used
# 2   Audi  2013          4.5  Electric       Manual   181601       New
# 3  Tesla  2011          4.1    Diesel    Automatic    68682       New
# 4   Ford  2009          2.6    Diesel       Manual   223009  Like New
#
#       Price     Model
# 0  26613.92   Model X
# 1  14679.61  5 Series
# 2  44402.61        A4
# 3  86374.33   Model Y
# 4  73577.10   Mustang

# %%
# Reorganizar las columnas, colocando 'Model' antes de 'Year'
columnas = ["Brand", "Model", "Year", "Engine Size", "Fuel Type", "Transmission", "Mileage", "Condition", "Price"]
datos = datos[columnas]

# %%
# Crear nueva característica: Edad del auto
datos["Car_Age"] = 2025 - datos["Year"]
datos = datos.drop(columns=["Year"])  # Eliminamos la columna original

# %%
# Función para convertir texto a números con inicio en 1
def encode_text_columns(df, columns):
    label_encoders = {}
    for col in columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col]) + 1  # Sumar 1 para que inicie en 1
        label_encoders[col] = dict(zip(le.classes_, range(1, len(le.classes_) + 1)))
    return df, label_encoders

# %%
# Columnas a convertir a números
categorical_features = ["Brand", "Model", "Fuel Type", "Transmission", "Condition"]
datos, label_encoders = encode_text_columns(datos, categorical_features)

# %%
datos.head()
# Out:
#    Car ID  Brand  Engine Size  Fuel Type  Transmission  Mileage  Condition  \
# 0       1      6          2.3          4             2   114832          2
# 1       2      2          4.4          2             2   143190          3
# 2       3      1          4.5          2             2   181601          2
# 3       4      6          4.1          1             1    68682          2
# 4       5      3          2.6          1             2   223009          1
#
#       Price  Model  Car_Age
# 0  26613.92     20        9
# 1  14679.61      2        7
# 2  44402.61      4       12
# 3  86374.33     21       14
# 4  73577.10     22       16

# %%
# Mostrar las asignaciones
for col, mapping in label_encoders.items():
    print(f"{col}: {mapping}")
# Out:
# Brand: {'Audi': 1, 'BMW': 2, 'Ford': 3, 'Honda': 4, 'Mercedes': 5, 'Tesla': 6, 'Toyota': 7}
# Model: {'3 Series': 1, '5 Series': 2, 'A3': 3, 'A4': 4, 'Accord': 5, 'C-Class': 6, 'CR-V': 7, 'Camry': 8, 'Civic': 9, 'Corolla': 10, 'E-Class': 11, 'Explorer': 12, 'Fiesta': 13, 'Fit': 14, 'Focus': 15, 'GLA': 16, 'GLC': 17, 'Model 3': 18, 'Model S': 19, 'Model X': 20, 'Model Y': 21, 'Mustang': 22, 'Prius': 23, 'Q5': 24, 'Q7': 25, 'RAV4': 26, 'X3': 27, 'X5': 28}
# Fuel Type: {'Diesel': 1, 'Electric': 2, 'Hybrid': 3, 'Petrol': 4}
# Transmission: {'Automatic': 1, 'Manual': 2}
# Condition: {'Like New': 1, 'New': 2, 'Used': 3}

# %%
# Características (X) y etiqueta (y)
X = datos.drop(columns=["Price"])
y = datos["Price"]

# %%
# Entrenar el modelo de regresión lineal
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicción con nuevos valores
ejemplo_auto = np.hstack((scaler.transform([[2.0, 30000, 5]]), encoder.transform([["Tesla", "Model S", "Electric", "Automatic", "New"]])))
prediccion_precio = model.predict(ejemplo_auto)
print(f"El precio estimado del auto es: {prediccion_precio[0]:.2f}")
# Out:
# El precio estimado del auto es: 50713.05
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
modelo.score(X_procesada, y_procesada)
# Out:
# 0.0040513902452794515
